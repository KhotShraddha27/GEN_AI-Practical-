# %% [markdown]
# <a href="https://colab.research.google.com/github/KhotShraddha27/GEN_AI-Practical-/blob/main/Expt03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U langchain langchain-community langchain-text-splitters pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 36.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.1/329.1 kB 20.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.4/157.4 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langgraph-prebuilt
#     Found existing installation: langgraph-prebuilt 1.0.6
#     Uninstalling langgraph-prebuilt-1.0.6:
#       Successfully uninstalled langgraph-prebuilt-1.0.6
#   Attempting uninstall: langgraph
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-1dc40e4e-6466-4269-aafb-35cf42e3caa0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1dc40e4e-6466-4269-aafb-35cf42e3caa0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader

pdf_path = "Expt03.pdf"   # change if filename differs
loader = PyPDFLoader(pdf_path)

documents = loader.load()

print("Pages:", len(documents))
print(documents[0].page_content[:500])
# Out:
# Pages: 1
# T.Y.B.Tech CSE(AIML)                                                             Subject: Agentic Systems Lab
#
#
# Department of Computer Science and Engineering(AIML)
#
#
#
# Experiment No. : 3
#
# Title: Implementation of PDF Document Ingestion and Text Chunking for Retrieval-Augmented
# Generation (RAG).
#
# Objectives:
# 1. To extract textual content from a PDF document.
# 2. To apply text chunking techniques to split large documents into smaller meaningful parts.
#
# Key Concepts: Document Ingesti

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = text_splitter.split_documents(documents)

print("Chunks:", len(chunks))
print(chunks[0].page_content[:400])
print(chunks[1].page_content[:400])
print(chunks[2].page_content[:400])
# Out:
# Chunks: 3
# T.Y.B.Tech CSE(AIML)                                                             Subject: Agentic Systems Lab
#
#
# Department of Computer Science and Engineering(AIML)
#
#
#
# Experiment No. : 3
#
# Title: Implementation of PDF Document Ingestion and Text Chunking for Retrieval-Augmented
# Generation (RAG).
#
# Objectives:
# 1. To extract textual content from a PDF document.
# 2. To apply text chunking
# Key Concepts: Document Ingestion, Text Chunking.
# Theory:
# What is PDF Ingestion?
# PDF ingestion means reading a PDF file and converting it into text so that a computer program
# can understand and process it.
# What is Text Chunking?
# Large documents are too long for AI models to process at once. So, we split the text into small
# pieces called chunks.
# Each chunk:
#  Contains a small amount of text
# Why is this important for RAG?
#  Helps in fast and accurate information retrieval
#  Improves answer quality
#  Avoids model input size limits
# Algorithm
# ...

# %%
print(chunks[2].page_content)
print(chunks[2].metadata)
# Out:
# Why is this important for RAG?
#  Helps in fast and accurate information retrieval
#  Improves answer quality
#  Avoids model input size limits
# Algorithm
# 1. Install required Python libraries.
# 2. Upload PDF File.
# 3. Load the PDF Document.
# 4. Apply Text Chunking.
# 5. View Sample Chunk.
# 6. Observe and analyze outputs.
# {'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-01-27T06:16:08+00:00', 'author': 'Online2PDF.com', 'moddate': '2026-01-27T06:16:08+00:00', 'source': 'Expt03.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}

# %%
for i, chunk in enumerate(chunks):
    print(f"\n--- Chunk {i+1} ---")
    print(chunk.page_content)
    print("Metadata:", chunk.metadata)
# Out:
# --- Chunk 1 ---
# T.Y.B.Tech CSE(AIML)                                                             Subject: Agentic Systems Lab
#
#
# Department of Computer Science and Engineering(AIML)
#
#
#
# Experiment No. : 3
#
# Title: Implementation of PDF Document Ingestion and Text Chunking for Retrieval-Augmented
# Generation (RAG).
#
# Objectives:
# 1. To extract textual content from a PDF document.
# 2. To apply text chunking techniques to split large documents into smaller meaningful parts.
# Metadata: {'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-01-27T06:16:08+00:00', 'author': 'Online2PDF.com', 'moddate': '2026-01-27T06:16:08+00:00', 'source': 'Expt03.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}
#
# --- Chunk 2 ---
# Key Concepts: Document Ingestion, Text Chunking.
# Theory:
# What is PDF Ingestion?
# PDF ingestion means reading a PDF file and converting it into text so that a computer program
# can understand and process it.
# ...
